# %% [markdown]
# Resultados - Paper de clasificación de actividad física empleando dataset WPM

# %%
# !where python
# !pip show numpy

import numpy as np

# %% [markdown]
# Cases dataset PI

# %%
ruta = 'D:\\DATA_PMP_File_Server\\output\\cases_dataset_PI\\case_PI_BRF_17_classes\\accuracies_test.npz'
BRF_data = np.load(ruta)
media_accuracies = BRF_data['mean']
std_accuracies = BRF_data['std']
print(f'Media accuracie BRF 17 classes: {media_accuracies:.2f}')
print(f'STD accuracies BRF 17 classes: {std_accuracies:.2f}')
# Out:
# Media accuracie BRF 17 classes: 61.35
# STD accuracies BRF 17 classes: 0.36
